# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=98826ee963ea4a7bbb1f647797789b037c4d54f71367bd93ddf2c19ca0ff283b
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
import os
import cv2
import glob
from google.colab.patches import cv2_imshow
import numpy as np
import pandas as pd
from PIL import Image 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt

def read_img(path):
  img = cv2.imread(path)
  (h,w)=img.shape[:2]
  width = 256
  ratio = width / float (w)
  height = int (h * ratio)
  return cv2.resize(img,(width, height)) 

known_encodings = []
known_names = [] 

for file in glob.iglob('/content/drive/My Drive/input/*jpg'):
  k_img = read_img(file)
  img_enc = face_recognition.face_encodings(k_img)[0]
  known_encodings.append(img_enc)
  known_names.append(file)

"""
labels = []
labels.append(known_encodings)
labels.append(known_names)
labels = pd.DataFrame(labels)
labels.to_csv('labels.csv', index=False)
labels_t = labels.T # or df1.transpose()
labels_t.columns=['k_encodings','k_names']
"""

unknown_dir = '/content/drive/My Drive/output/left_eye/left_eye1.jpg'
#for file in glob.iglob('/content/drive/My Drive/Unknown_Faces/*jpg'):
#print("Processing",file)
img = read_img(unknown_dir)
img_enc = face_recognition.face_encodings(img)[0]
  
result = face_recognition.compare_faces(known_encodings, img_enc)

  #print(face_recognition.face_distance(known_encodings, img_enc))
  #print(result)

for i in range(len(result)):
  if result[i]== True:
    distance = np.linalg.norm(known_encodings - img_enc)
    print(distance)
    if distance <= 4:
      name = known_names[i]
      im = cv2.imread(name)
      (top, right, bottom, left) = face_recognition.face_locations(img)[0]
      cv2.rectangle(img,(left,top),(right,bottom),(0,0,255),2)
        #cv2.putText(img, name, (left, bottom+20), cv2.FONT_HERSHEY_PLAIN, 1, (255,255,255), 1)
      cv2_imshow(im)
      cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-22377186cb8e> in <module>()
#      40 #for file in glob.iglob('/content/drive/My Drive/Unknown_Faces/*jpg'):
#      41 #print("Processing",file)
# ---> 42 img = read_img(unknown_dir)
#      43 img_enc = face_recognition.face_encodings(img)[0]
#      44
#
# <ipython-input-6-22377186cb8e> in read_img(path)
#      12 def read_img(path):
#      13   img = cv2.imread(path)
# ---> 14   (h,w)=img.shape[:2]
#      15   width = 256
#      16   ratio = width / float (w)
#
# AttributeError: 'NoneType' object has no attribute 'shape'
